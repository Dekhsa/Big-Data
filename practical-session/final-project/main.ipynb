# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('all_songs_data_50k.csv')
df
# Out:
#                             _id           recipient  \
# 0      6853b58d17e1fe68eff7d1bf                mark
# 1      6853b58717e1fe68eff7d1be           dimas ali
# 2      6853b58417e1fe68eff7d1bd                2229
# 3      6853b56717e1fe68eff7d1bc  savira ramadhani m
# 4      6853b56617e1fe68eff7d1bb                drix
# ...                         ...                 ...
# 49995  684ee56f17e1fe68eff710d6              joshua
# 49996  684ee56c17e1fe68eff710d5                 yna
# 49997  684ee56b17e1fe68eff710d4             maritza
# 49998  684ee56b17e1fe68eff710d3              alfred
# 49999  684ee56217e1fe68eff710d2                awik
#
#                                                  message  \
# 0      Hi, uhm, yeah, everytime na tingnan ko yung re...
# 1      I don't know if you still care about me or not...
# 2      I'll always love you from this day on, now and...
# 3                                                      .
# ...

# %%
df2 = pd.read_csv('MENTAH_hasil_pencarian_nama_tergabung.csv')
df2
# Out:
#                            _id recipient  \
# 0     684b8e6417e1fe68eff67525  muhammad
# 1     683f411a1fc54584f671495f  muhammad
# 2     683f0b991fc54584f6713550  muhammad
# 3     683d6ff31fc54584f670bac0  muhammad
# 4     683c4d471fc54584f67054d7  muhammad
# ...                        ...       ...
# 3534  68138f211fc54584f668c3bf       ayu
# 3535  6812cf9b1fc54584f668a368       ayu
# 3536  680bd9c01fc54584f6678c2e       ayu
# 3537  680b59f31fc54584f6676859       ayu
# 3538  6809e4571fc54584f666ffca       ayu
#
#                                                 message  \
# 0     𝒽𝒶𝓅𝓅𝓎 𝒷𝒾𝓇𝓉𝒽𝒹𝒶𝓎 𝒹𝑒𝒶𝓇🎂!!\n𝑜𝓃 𝓎𝑜𝓊𝓇 𝓈𝓅𝑒𝒸𝒾𝒶𝓁 𝒹𝒶𝓎, 𝒾...
# 1     hi muhammad, i hope you know that you are the ...
# 2                   buatla first move. mintakla no aku
# 3              aloo. sini☝sebelah sini☝ iya yg ini :')
# 4     stay strong muhammad, know that you're worth.....
# ...                                                 ...
# 3534  hey! i've seen u once sa morato playing billia...
# ...

# %%
df[df.duplicated()]
# Out:
#                             _id  recipient  \
# 15     6853b52917e1fe68eff7d1b1      fitri
# 105    6853b27b17e1fe68eff7d158     teagan
# 345    6853ab2117e1fe68eff7d06a      yekai
# 346    6853ab1517e1fe68eff7d069  faathir k
# 495    6853a64617e1fe68eff7cfd5      chang
# ...                         ...        ...
# 49530  684eeb3017e1fe68eff712a3        bea
# 49575  684eea9d17e1fe68eff71277        ara
# 49635  684eea0417e1fe68eff7123c  ramaaaaaa
# 49935  684ee65217e1fe68eff71111       rama
# 49980  684ee5a117e1fe68eff710e5       rohn
#
#                                                  message  \
# 15                                 nyebelin lo egois njs
# 105    Hey T, I know that you don’t know what you did...
# 345    (🙇🏻‍♀️?) niyayakap niya knees niya tapos nakay...
# 346    hllo thir! kalo lu tau ttg ini one day, all i ...
# 495    maybe in another universe ill be able to conve...
# ...                                                  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   _id          50000 non-null  object
#  1   recipient    50000 non-null  object
#  2   message      49999 non-null  object
#  3   song_id      50000 non-null  object
#  4   song_name    50000 non-null  object
#  5   song_artist  50000 non-null  object
#  6   song_image   49999 non-null  object
#  7   created_at   50000 non-null  object
# dtypes: object(8)
# memory usage: 3.1+ MB

# %% [markdown]
# ## Unique Category

# %%
print('song artist sum    : ', df['song_artist'].unique().shape[0])
print('song name sum      : ', df['song_name'].unique().shape[0])
# Out:
# song artist sum    :  1927
# song name sum      :  3934

# %%
empty_message = df['message'].isnull().sum() + df['message'].eq('').sum() + df['message'].eq(' ').sum() + df['message'].eq('.').sum() + df['message'].eq(',').sum()
print('empty message sum : ', empty_message)
# Out:
# empty message sum :  402

# %% [markdown]
# # Time Series Visualization: Number of Songs Released Per Month
#
# This section visualizes the number of songs released per month as a time series using the 'created_at' column.

# %%
# Time Series Plot: Number of Songs Released Per Month using 'created_at'
if 'created_at' in df.columns:
    df['created_at'] = pd.to_datetime(df['created_at'], errors='coerce')
    df = df.dropna(subset=['created_at'])
    df['release_month'] = df['created_at'].dt.to_period('M').astype(str)
    songs_per_month = df['release_month'].value_counts().sort_index()
    plt.figure(figsize=(16, 6))
    sns.lineplot(x=songs_per_month.index, y=songs_per_month.values, marker='o')
    plt.title('Number of Songs Released Per Month')
    plt.xlabel('Month')
    plt.ylabel('Number of Songs')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.tight_layout()
    plt.show()
else:
    print("No 'created_at' column found. Please check your dataframe columns and update the code if needed.")
# Out:
# C:\Users\62812\AppData\Local\Temp\ipykernel_45104\3519103851.py:5: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df['release_month'] = df['created_at'].dt.to_period('M').astype(str)
