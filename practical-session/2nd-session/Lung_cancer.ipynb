# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('datasets/cancer patient data sets.csv')
df
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0        0         P1   33       1              2            4             5
# 1        1        P10   17       1              3            1             5
# 2        2       P100   35       1              4            5             6
# 3        3      P1000   37       1              7            7             7
# 4        4       P101   46       1              6            8             7
# ..     ...        ...  ...     ...            ...          ...           ...
# 995    995       P995   44       1              6            7             7
# 996    996       P996   37       2              6            8             7
# 997    997       P997   25       2              4            5             6
# 998    998       P998   18       2              6            8             7
# 999    999       P999   47       1              6            5             6
#
# ...

# %% [markdown]
# # Data Overview
#
# Let's start by viewing the first few rows and the column names of the dataset.

# %%
# Show first 5 rows and column names
df.head()
# Out:
#    index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0      0         P1   33       1              2            4             5
# 1      1        P10   17       1              3            1             5
# 2      2       P100   35       1              4            5             6
# 3      3      P1000   37       1              7            7             7
# 4      4       P101   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  Fatigue  \
# 0                     4             3                     2  ...        3
# 1                     3             4                     2  ...        1
# 2                     5             5                     4  ...        8
# 3                     7             6                     7  ...        4
# 4                     7             7                     6  ...        3
#
# ...

# %% [markdown]
# # Data Types and Missing Values
#
# Check the data types and count missing values for each column.

# %%
# Data types and missing values
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     1000 non-null   int64
#  1   Patient Id                1000 non-null   object
#  2   Age                       1000 non-null   int64
#  3   Gender                    1000 non-null   int64
#  4   Air Pollution             1000 non-null   int64
#  5   Alcohol use               1000 non-null   int64
#  6   Dust Allergy              1000 non-null   int64
#  7   OccuPational Hazards      1000 non-null   int64
#  8   Genetic Risk              1000 non-null   int64
#  9   chronic Lung Disease      1000 non-null   int64
#  10  Balanced Diet             1000 non-null   int64
#  11  Obesity                   1000 non-null   int64
#  12  Smoking                   1000 non-null   int64
#  13  Passive Smoker            1000 non-null   int64
# ...

# %% [markdown]
# # Descriptive Statistics
#
# Summary statistics for numerical and categorical columns.

# %%
# Descriptive statistics for all columns
df.describe(include='all')
# Out:
#               index Patient Id          Age       Gender  Air Pollution  \
# count   1000.000000       1000  1000.000000  1000.000000      1000.0000
# unique          NaN       1000          NaN          NaN            NaN
# top             NaN       P999          NaN          NaN            NaN
# freq            NaN          1          NaN          NaN            NaN
# mean     499.500000        NaN    37.174000     1.402000         3.8400
# std      288.819436        NaN    12.005493     0.490547         2.0304
# min        0.000000        NaN    14.000000     1.000000         1.0000
# 25%      249.750000        NaN    27.750000     1.000000         2.0000
# 50%      499.500000        NaN    36.000000     1.000000         3.0000
# 75%      749.250000        NaN    45.000000     2.000000         6.0000
# max      999.000000        NaN    73.000000     2.000000         8.0000
#
#         Alcohol use  Dust Allergy  OccuPational Hazards  Genetic Risk  \
# ...

# %% [markdown]
# # Unique Values in Categorical Columns
#
# Check unique values for each categorical column.

# %%
# Unique values for object (categorical) columns
cat_cols = df.select_dtypes(include='object').columns
{col: df[col].unique() for col in cat_cols}
# Out:
# {'Patient Id': array(['P1', 'P10', 'P100', 'P1000', 'P101', 'P102', 'P103', 'P104',
#         'P105', 'P106', 'P107', 'P108', 'P109', 'P11', 'P110', 'P111',
#         'P112', 'P113', 'P114', 'P115', 'P116', 'P117', 'P118', 'P119',
#         'P12', 'P120', 'P121', 'P122', 'P123', 'P124', 'P125', 'P126',
#         'P127', 'P128', 'P129', 'P13', 'P130', 'P131', 'P132', 'P133',
#         'P134', 'P135', 'P136', 'P137', 'P138', 'P139', 'P14', 'P140',
#         'P141', 'P142', 'P143', 'P144', 'P145', 'P146', 'P147', 'P148',
#         'P149', 'P15', 'P150', 'P151', 'P152', 'P153', 'P154', 'P155',
#         'P156', 'P157', 'P158', 'P159', 'P16', 'P160', 'P161', 'P162',
#         'P163', 'P164', 'P165', 'P166', 'P167', 'P168', 'P169', 'P17',
#         'P170', 'P171', 'P172', 'P173', 'P174', 'P175', 'P176', 'P177',
#         'P178', 'P179', 'P18', 'P180', 'P181', 'P182', 'P183', 'P184',
#         'P185', 'P186', 'P187', 'P188', 'P189', 'P19', 'P190', 'P191',
# ...

# %% [markdown]
# # Visualizations
#
# ## 1. Distribution of Cancer Levels

# %%
plt.figure(figsize=(7,5))
sns.countplot(data=df, x='Level', palette='Set2')
plt.title('Distribution of Cancer Levels')
plt.xlabel('Cancer Level')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\62812\AppData\Local\Temp\ipykernel_42504\406168399.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Level', palette='Set2')

# %% [markdown]
# ## 2. Age Distribution by Cancer Level

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x='Level', y='Age', palette='coolwarm')
plt.title('Age Distribution by Cancer Level')
plt.xlabel('Cancer Level')
plt.ylabel('Age')
plt.show()
# Out:
# C:\Users\62812\AppData\Local\Temp\ipykernel_42504\3743594754.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Level', y='Age', palette='coolwarm')

# %% [markdown]
# ## 3. Gender Distribution by Cancer Level

# %%
plt.figure(figsize=(7,5))
sns.countplot(data=df, x='Gender', hue='Level', palette='pastel')
plt.title('Gender Distribution by Cancer Level')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Cancer Level')
plt.show()

# %% [markdown]
# ## 4. Correlation Heatmap (Numeric Features)

# %%
plt.figure(figsize=(15,9))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='mako')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## 5. Smoking Status vs Cancer Level

# %%
if 'Smoking' in df.columns:
    plt.figure(figsize=(7,5))
    sns.countplot(data=df, x='Smoking', hue='Level', palette='Set1')
    plt.title('Smoking Status by Cancer Level')
    plt.xlabel('Smoking Status')
    plt.ylabel('Count')
    plt.legend(title='Cancer Level')
    plt.show()
else:
    print('Smoking column not found.')

# %% [markdown]
# ## 6. Pairplot for Selected Features

# %% [markdown]
# # Conclusion
#
# This completes the EDA and visualization for the lung cancer dataset. You can further explore relationships or perform feature engineering as needed.
